# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation
import pandas as pd

# %%
i = 0
data = pd.read_csv(f"data/time={i}.csv")
x = np.linspace(0,198,199)
data
# Out:
#      Magnetic_Field  Electric_Field
# 0               0.0         0.00012
# 1               0.0         0.00000
# 2               0.0         0.00000
# 3               0.0         0.00000
# 4               0.0         0.00000
# ..              ...             ...
# 194             0.0         0.00000
# 195             0.0         0.00000
# 196             0.0         0.00000
# 197             0.0         0.00000
# 198             0.0         0.00000
#
# [199 rows x 2 columns]

# %%
# %matplotlib notebook
plt.plot(x,data["Magnetic_Field"])
plt.xlim([0,198])
plt.ylim([0,1])
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="639.9833333333333">

# %%
x = np.linspace(0,198,199)
for i in range(0,100):
    
    data = pd.read_csv(f"data/time={i}.csv")
    
    # %matplotlib notebook
    plt.plot(x,data["Magnetic_Field"])
    plt.xlim([0,198])
    plt.ylim([0,1])
    
    plt.show()
# Out:
# <img src="data:image/png;base64,..." width="639.9833333333333">
# <img src="data:image/png;base64,..." width="639.9833333333333">
# <img src="data:image/png;base64,..." width="892.9666666666667">
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[26], line 10
#       8 plt.xlim([0,198])
#       9 plt.ylim([0,1])
# ---> 10 plt.pause(5)
#      11 plt.show()
#
# File ~/miniconda3/envs/Science/lib/python3.8/site-packages/matplotlib/pyplot.py:438, in pause(interval)
#     436         canvas.draw_idle()
#     437     show(block=False)
# --> 438     canvas.start_event_loop(interval)
#     439 else:
#     440     time.sleep(interval)
#
# File ~/miniconda3/envs/Science/lib/python3.8/site-packages/matplotlib/backend_bases.py:2408, in FigureCanvasBase.start_event_loop(self, timeout)
#    2406 while self._looping and counter * timestep < timeout:
#    2407     self.flush_events()
# ...
